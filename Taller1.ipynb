# %%
# !git clone https://github.com/MECA4605-Aprendizaje-no-supervisado/taller_1.git
# Out:
# Cloning into 'taller_1'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 14 (delta 4), reused 13 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 337.27 KiB | 21.08 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd taller_1
# Out:
# /content/taller_1

# %%
# !ls
# Out:
# data  figs  S1_LC_Taller_PCA.ipynb  S2_LC_Taller_SVD.ipynb
